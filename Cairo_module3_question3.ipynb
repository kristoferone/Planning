# %% [markdown]
# <a href="https://colab.research.google.com/github/kristoferone/Planning/blob/master/Cairo_module3_question3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
df = pd.read_excel('https://query.data.world/s/nhjsypsntubopyuvnpb3esczjqmzfm')

# %%
country = df['Country']

# %%
weighted_score = df['Weighted Score']

# %%
plt.plot(country[:29], weighted_score[:29])
plt.tight_layout()
plt.xticks(rotation=90)
plt.title('DESI Connectivity 2018')
plt.savefig('desi_2018_connectivity', bbox_inches = "tight")

# %%
plt.show()
